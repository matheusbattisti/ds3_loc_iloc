# %%
#importando libs
import pandas as pd

#chamando o dataset
df = pd.read_csv('tomslee_airbnb_aarhus_1003_2017-03-30.csv')

#testando dataset
df.head()
# Out:
#     room_id   host_id    room_type  borough  neighborhood  reviews  \
# 0   8395271   4159382  Shared room      NaN            24        0
# 1  12799204  29578114  Shared room      NaN            11        2
# 2   4623614  19645205  Shared room      NaN            24       29
# 3   6778463  20693961  Shared room      NaN             3        0
# 4  12130889  21971193  Shared room      NaN            24        2
#
#    overall_satisfaction  accommodates  bedrooms  price  minstay   latitude  \
# 0                   0.0             1       1.0   67.0      NaN  56.162881
# 1                   0.0             2       1.0   30.0      NaN  56.171913
# 2                   4.5             6       1.0   34.0      NaN  56.157104
# 3                   0.0             5       1.0   10.0      NaN  56.173203
# 4                   0.0             1       1.0   16.0      NaN  56.158612
#
#    longitude               last_modified
# 0  10.203689  2017-03-30 22:33:40.701869
# ...

# %%
#loc com índice
df.loc[[5]]
# Out:
#    room_id   host_id    room_type  borough  neighborhood  reviews  \
# 5  8819543  29014983  Shared room      NaN            24       48
#
#    overall_satisfaction  accommodates  bedrooms  price  minstay   latitude  \
# 5                   5.0             1       1.0   31.0      NaN  56.164447
#
#    longitude               last_modified
# 5  10.189526  2017-03-30 22:33:38.883409

# %%
#loc com array
df.loc[[0,1,2]]
# Out:
#     room_id   host_id    room_type  borough  neighborhood  reviews  \
# 0   8395271   4159382  Shared room      NaN            24        0
# 1  12799204  29578114  Shared room      NaN            11        2
# 2   4623614  19645205  Shared room      NaN            24       29
#
#    overall_satisfaction  accommodates  bedrooms  price  minstay   latitude  \
# 0                   0.0             1       1.0   67.0      NaN  56.162881
# 1                   0.0             2       1.0   30.0      NaN  56.171913
# 2                   4.5             6       1.0   34.0      NaN  56.157104
#
#    longitude               last_modified
# 0  10.203689  2017-03-30 22:33:40.701869
# 1  10.136547  2017-03-30 22:33:38.894370
# 2  10.203791  2017-03-30 22:33:38.891426

# %%
df.loc[2:20]
# Out:
#      room_id   host_id        room_type  borough  neighborhood  reviews  \
# 2    4623614  19645205      Shared room      NaN            24       29
# 3    6778463  20693961      Shared room      NaN             3        0
# 4   12130889  21971193      Shared room      NaN            24        2
# 5    8819543  29014983      Shared room      NaN            24       48
# 6    9398947  48746007      Shared room      NaN            24        0
# 7   16091993  79205128      Shared room      NaN            24        6
# 8   11275615   6620412  Entire home/apt      NaN             6        0
# 9    1116177   1693364  Entire home/apt      NaN            24        0
# 10   1256165   6842647  Entire home/apt      NaN            24        6
# 11     60108    281902  Entire home/apt      NaN             3       12
# 12  17382570  67882822  Entire home/apt      NaN            24        0
# 13   7048623  33439155  Entire home/apt      NaN            24       22
# ...

# %%
#setando um index para podermos trabalhar com o nome das linhas
df2 = df.set_index('room_id')

#testando a alteração
df2.head()
# Out:
#            host_id    room_type  borough  neighborhood  reviews  \
# room_id
# 8395271    4159382  Shared room      NaN            24        0
# 12799204  29578114  Shared room      NaN            11        2
# 4623614   19645205  Shared room      NaN            24       29
# 6778463   20693961  Shared room      NaN             3        0
# 12130889  21971193  Shared room      NaN            24        2
#
#           overall_satisfaction  accommodates  bedrooms  price  minstay  \
# room_id
# 8395271                    0.0             1       1.0   67.0      NaN
# 12799204                   0.0             2       1.0   30.0      NaN
# 4623614                    4.5             6       1.0   34.0      NaN
# 6778463                    0.0             5       1.0   10.0      NaN
# 12130889                   0.0             1       1.0   16.0      NaN
#
#            latitude  longitude               last_modified
# room_id
# 8395271   56.162881  10.203689  2017-03-30 22:33:40.701869
# ...

# %%
#agora podemos chamar pelo índice com nome, por exemplo:
df2.loc[8395271]
# Out:
# host_id                                    4159382
# room_type                              Shared room
# borough                                        NaN
# neighborhood                                    24
# reviews                                          0
# overall_satisfaction                             0
# accommodates                                     1
# bedrooms                                         1
# price                                           67
# minstay                                        NaN
# latitude                                   56.1629
# longitude                                  10.2037
# last_modified           2017-03-30 22:33:40.701869
# Name: 8395271, dtype: object

# %%
#selecionar apenas as colunas que queremos também é possivel
df2.loc[[8395271, 12130889, 4623614], ['room_type', 'price', 'last_modified']]
# Out:
#             room_type  price               last_modified
# room_id
# 8395271   Shared room   67.0  2017-03-30 22:33:40.701869
# 12130889  Shared room   16.0  2017-03-30 22:33:38.885745
# 4623614   Shared room   34.0  2017-03-30 22:33:38.891426
