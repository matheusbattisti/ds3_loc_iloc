# %%
#importando libs utilizadas no tutorial
import pandas as pd

#chamando o dataset
df = pd.read_csv('nba_draft_2015.csv')

#testando dataset
df.head()
# Out:
#                Player Position                  ID  Draft Year  Projected SPM  \
# 0  Karl-Anthony Towns        C  karl-anthony-towns        2015       1.030606
# 1     Justise Winslow       SF     justise-winslow        2015       0.875329
# 2     Stanley Johnson       SF     stanley-johnson        2015       0.679493
# 3       Jahlil Okafor        C       jahlil-okafor        2015       0.521661
# 4    D`Angelo Russell       PG    d-angelo-russell        2015       0.511967
#
#    Superstar   Starter  Role Player      Bust
# 0   0.134767  0.427183     0.163083  0.274967
# 1   0.083529  0.510905     0.176767  0.228800
# 2   0.067800  0.423733     0.278500  0.229967
# 3   0.058717  0.409900     0.235533  0.295850
# 4   0.152033  0.342283     0.096583  0.409100

# %%
#loc com índice
df.loc[[5]]
# Out:
#            Player Position              ID  Draft Year  Projected SPM  \
# 5  Dakari Johnson        C  dakari-johnson        2015       0.491787
#
#    Superstar   Starter  Role Player      Bust
# 5   0.021341  0.367544     0.417572  0.193544

# %%
#loc com array
df.loc[[0,1,2]]
# Out:
#                Player Position                  ID  Draft Year  Projected SPM  \
# 0  Karl-Anthony Towns        C  karl-anthony-towns        2015       1.030606
# 1     Justise Winslow       SF     justise-winslow        2015       0.875329
# 2     Stanley Johnson       SF     stanley-johnson        2015       0.679493
#
#    Superstar   Starter  Role Player      Bust
# 0   0.134767  0.427183     0.163083  0.274967
# 1   0.083529  0.510905     0.176767  0.228800
# 2   0.067800  0.423733     0.278500  0.229967

# %%
df.loc[4:8]
# Out:
#                     Player Position                       ID  Draft Year  \
# 4         D`Angelo Russell       PG         d-angelo-russell        2015
# 5           Dakari Johnson        C           dakari-johnson        2015
# 6             Devin Booker       SG           3-devin-booker        2015
# 7      Willie Cauley-Stein        C      willie-cauley-stein        2015
# 8  Rondae Hollis-Jefferson       SF  rondae-hollis-jefferson        2015
#
#    Projected SPM  Superstar   Starter  Role Player      Bust
# 4       0.511967   0.152033  0.342283     0.096583  0.409100
# 5       0.491787   0.021341  0.367544     0.417572  0.193544
# 6       0.472577   0.073367  0.324467     0.390167  0.212000
# 7       0.351171   0.047114  0.405990     0.243186  0.303710
# 8       0.311909   0.014590  0.368533     0.392481  0.224396

# %%
#setando um index para podermos trabalhar com o nome das linhas
df2 = df.set_index('Player')

#testando a alteração
df2.head()
# Out:
#                    Position                  ID  Draft Year  Projected SPM  \
# Player
# Karl-Anthony Towns        C  karl-anthony-towns        2015       1.030606
# Justise Winslow          SF     justise-winslow        2015       0.875329
# Stanley Johnson          SF     stanley-johnson        2015       0.679493
# Jahlil Okafor             C       jahlil-okafor        2015       0.521661
# D`Angelo Russell         PG    d-angelo-russell        2015       0.511967
#
#                     Superstar   Starter  Role Player      Bust
# Player
# Karl-Anthony Towns   0.134767  0.427183     0.163083  0.274967
# Justise Winslow      0.083529  0.510905     0.176767  0.228800
# Stanley Johnson      0.067800  0.423733     0.278500  0.229967
# Jahlil Okafor        0.058717  0.409900     0.235533  0.295850
# D`Angelo Russell     0.152033  0.342283     0.096583  0.409100

# %%
#agora podemos chamar pelo índice com nome, por exemplo:
df2.loc['Justise Winslow']
# Out:
# Position                      SF
# ID               justise-winslow
# Draft Year                  2015
# Projected SPM           0.875329
# Superstar              0.0835286
# Starter                 0.510905
# Role Player             0.176767
# Bust                      0.2288
# Name: Justise Winslow, dtype: object

# %%
#selecionar apenas as colunas que queremos também é possivel, neste exemplo um array com as linhas e outro de colunas
df2.loc[['Karl-Anthony Towns', 'Stanley Johnson', 'D`Angelo Russell'], ['Position', 'ID']]
# Out:
#                    Position                  ID
# Player
# Karl-Anthony Towns        C  karl-anthony-towns
# Stanley Johnson          SF     stanley-johnson
# D`Angelo Russell         PG    d-angelo-russell

# %%
'''
    Estamos localizando os atletas com probabilidade maior ou igual a 10% de serem superstars
    obs: estou multiplicando por 100, para ficar mais facil o entendimento
'''
df.loc[(df['Superstar']*100) >= 10]
# Out:
#                   Player Position                  ID  Draft Year  \
# 0     Karl-Anthony Towns        C  karl-anthony-towns        2015
# 4       D`Angelo Russell       PG    d-angelo-russell        2015
# 77           Joel Embiid        C         joel-embiid        2014
# 78          Marcus Smart       PG        marcus-smart        2014
# 81        Andrew Wiggins       SG      andrew-wiggins        2014
# 158       Victor Oladipo       SG      victor-oladipo        2013
# 159         Nerlens Noel        C        nerlens-noel        2013
# 160          Otto Porter       SF         otto-porter        2013
# 239        Anthony Davis       PF     3-anthony-davis        2012
# 240         Bradley Beal       SG        bradley-beal        2012
# 241         Dion Waiters       SG        dion-waiters        2012
# 243      Thomas Robinson       PF     thomas-robinson        2012
# 324     Derrick Williams       PF  3-derrick-williams        2011
# ...

# %%
#Mudando os 5 primeiros registros para o ano de 2018
df2.loc[0:5, 'Draft Year'] = 2018

df2.head(5)
# Out:
#                    Position                  ID  Draft Year  Projected SPM  \
# Player
# Karl-Anthony Towns        C  karl-anthony-towns        2018       1.030606
# Justise Winslow          SF     justise-winslow        2018       0.875329
# Stanley Johnson          SF     stanley-johnson        2018       0.679493
# Jahlil Okafor             C       jahlil-okafor        2018       0.521661
# D`Angelo Russell         PG    d-angelo-russell        2018       0.511967
#
#                     Superstar   Starter  Role Player      Bust
# Player
# Karl-Anthony Towns   0.134767  0.427183     0.163083  0.274967
# Justise Winslow      0.083529  0.510905     0.176767  0.228800
# Stanley Johnson      0.067800  0.423733     0.278500  0.229967
# Jahlil Okafor        0.058717  0.409900     0.235533  0.295850
# D`Angelo Russell     0.152033  0.342283     0.096583  0.409100

# %%
# Selecionado a primeira linha do dataset
df.iloc[0]
# Out:
# Player           Karl-Anthony Towns
# Position                          C
# ID               karl-anthony-towns
# Draft Year                     2015
# Projected SPM               1.03061
# Superstar                  0.134767
# Starter                    0.427183
# Role Player                0.163083
# Bust                       0.274967
# Name: 0, dtype: object

# %%
 # Selecionando a última linha
df.iloc[-1]
# Out:
# Player           Calvin Bowman
# Position                     C
# ID               calvin-bowman
# Draft Year                2001
# Projected SPM         -1.68467
# Superstar                    0
# Starter             0.00506819
# Role Player           0.168629
# Bust                  0.826303
# Name: 1089, dtype: object

# %%
# Todos os dados da primeira coluna do dataset
df.iloc[:,0]
# Out:
# 0            Karl-Anthony Towns
# 1               Justise Winslow
# 2               Stanley Johnson
# 3                 Jahlil Okafor
# 4              D`Angelo Russell
# 5                Dakari Johnson
# 6                  Devin Booker
# 7           Willie Cauley-Stein
# 8       Rondae Hollis-Jefferson
# 9                    Trey Lyles
# 10                   Sam Dekker
# 11              Kelly Oubre Jr.
# 12                   Tyus Jones
# 13                 Kevon Looney
# 14                 Myles Turner
# 15              Cliff Alexander
# 16               Christian Wood
# 17               Frank Kaminsky
# 18           Michael Frazier II
# 19               Brandon Ashley
# 20                 Bobby Portis
# 21              Andrew Harrison
# 22                Rashad Vaughn
# 23               Aaron Harrison
# 24             Montrezl Harrell
# 25                   Quinn Cook
# 26                Cameron Payne
# 27             Chris McCullough
# 28              Justin Anderson
# ...

# %%
 # Do primeiro ao quinto dado da última coluna
df.iloc[0:5,-1]
# Out:
# 0    0.274967
# 1    0.228800
# 2    0.229967
# 3    0.295850
# 4    0.409100
# Name: Bust, dtype: float64

# %%
# resgatando as primeiras três linhas do dataset
df.iloc[0:3]
# Out:
#                Player Position                  ID  Draft Year  Projected SPM  \
# 0  Karl-Anthony Towns        C  karl-anthony-towns        2015       1.030606
# 1     Justise Winslow       SF     justise-winslow        2015       0.875329
# 2     Stanley Johnson       SF     stanley-johnson        2015       0.679493
#
#    Superstar   Starter  Role Player      Bust
# 0   0.134767  0.427183     0.163083  0.274967
# 1   0.083529  0.510905     0.176767  0.228800
# 2   0.067800  0.423733     0.278500  0.229967

# %%
# todos os dados da segunda e terceira coluna
df.iloc[:, 1:3]
# Out:
#      Position                       ID
# 0           C       karl-anthony-towns
# 1          SF          justise-winslow
# 2          SF          stanley-johnson
# 3           C            jahlil-okafor
# 4          PG         d-angelo-russell
# 5           C           dakari-johnson
# 6          SG           3-devin-booker
# 7           C      willie-cauley-stein
# 8          SF  rondae-hollis-jefferson
# 9          PF               trey-lyles
# 10         SF               sam-dekker
# 11         SF           kelly-oubre-jr
# 12         PG               tyus-jones
# 13         PF             kevon-looney
# 14         PF           2-myles-turner
# 15         PF          cliff-alexander
# 16         PF           christian-wood
# 17          C           frank-kaminsky
# 18         SG       michael-frazier-ii
# 19         PF           brandon-ashley
# 20         PF             bobby-portis
# 21         PG          andrew-harrison
# 22         SG            rashad-vaughn
# ...

# %%
# 1º,3º e 5º elementos e 6ª a 9ª colunas
df.iloc[[0,2,4], 5:8]
# Out:
#    Superstar   Starter  Role Player
# 0   0.134767  0.427183     0.163083
# 2   0.067800  0.423733     0.278500
# 4   0.152033  0.342283     0.096583
